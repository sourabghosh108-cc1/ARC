# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opentelemetry_semantic_conventions-0.62b1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/blake3-1.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/shellingham-1.5.4-py2.py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/prometheus_client-0.25.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/torch-2.10.0-3-cp312-cp312-manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/anthropic-0.97.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/typing_extensions-4.15.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/httpx-0.28.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/attrs-26.1.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/cuda_bindings-12.9.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/websockets-16.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pydantic_extra_types-2.11.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/python_multipart-0.0.27-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/jsonschema-4.26.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cutlass_dsl-4.5.0.dev0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.in
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/py_cpuinfo-9.0.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/h11-0.16.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/lark-1.2.2-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/googleapis_common_protos-1.74.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/partial_json_parser-0.2.1.1.post7-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/certifi-2026.4.22-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/docstring_parser-0.18.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/uvicorn-0.46.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/cloudpickle-3.1.2-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/httpcore-1.0.9-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opentelemetry_api-1.41.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/jsonschema_specifications-2025.9.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opentelemetry_exporter_otlp_proto_grpc-1.41.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/interegular-0.3.3-py37-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/cryptography-47.0.0-cp311-abi3-manylinux_2_34_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/outlines_core-0.2.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/cbor2-6.0.1-cp312-cp312-manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/torchaudio-2.10.0-cp312-cp312-manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/msgspec-0.21.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/watchfiles-1.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pycountry-26.2.16-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/httpx_sse-0.4.3-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/cuda_python-12.9.4-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/cachetools-7.0.6-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pip-resolve-report.json
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/click-8.3.3-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/sentencepiece-0.2.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/compressed_tensors-0.14.0.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pydantic_settings-2.14.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pyzmq-27.1.0-cp312-abi3-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/triton-3.6.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/starlette-0.52.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/huggingface_hub-0.36.2-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/model_hosting_container_standards-0.1.14-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/xgrammar-0.1.34-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/sse_starlette-3.4.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/dill-0.4.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/README.md
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pycparser-3.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/uvloop-0.22.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/typing_inspection-0.4.2-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requests-2.33.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/networkx-3.6.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/openai-2.33.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/referencing-0.37.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/vllm-0.19.0-cp38-abi3-manylinux_2_31_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/annotated_types-0.7.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/dnspython-2.8.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/hf_xet-1.4.3-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/torch_c_dlpack_ext-0.1.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/mpmath-1.3.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/SHA256SUMS
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/aiohappyeyeballs-2.6.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/tiktoken-0.12.0-cp312-cp312-manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/protobuf-6.33.6-cp39-abi3-manylinux2014_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/ijson-3.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/sniffio-1.3.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/jinja2-3.1.6-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/prometheus_fastapi_instrumentator-7.1.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/annotated_doc-0.0.4-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/grpcio-1.80.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/aiosignal-1.4.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/mcp-1.27.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/fastapi_cloud_cli-0.17.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/wheelhouse-manifest.json
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/six-1.17.0-py2.py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pyjwt-2.12.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/fastar-0.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opentelemetry_exporter_otlp_proto_common-1.41.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/flashinfer_cubin-0.6.6-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/rich_toolkit-0.19.7-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/fsspec-2026.4.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/apache_tvm_ffi-0.1.10-cp312-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_ml_py-13.595.45-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/tqdm-4.67.3-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/rignore-0.7.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/loguru-0.7.3-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/mistral_common-1.11.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/supervisor-4.3.0-py2.py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opentelemetry_proto-1.41.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/email_validator-2.3.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/multidict-6.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opencv_python_headless-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cutlass_dsl_libs_base-4.5.0.dev0-cp312-cp312-manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/tabulate-0.10.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/idna-3.13-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/jiter-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/gguf-0.18.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/flashinfer_python-0.6.6-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/python_json_logger-4.1.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/zipp-3.23.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/distro-1.9.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opentelemetry_sdk-1.41.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/markdown_it_py-4.0.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/depyf-0.20.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/regex-2026.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pydantic-2.13.3-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/anyio-4.13.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/httptools-0.7.1-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/openai_harmony-0.0.8-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/diskcache-5.6.3-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/propcache-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/einops-0.8.2-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opentelemetry_semantic_conventions_ai-0.5.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pydantic_core-2.46.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/python_dotenv-1.2.2-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_nvshmem_cu12-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/urllib3-2.6.3-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/torchvision-0.25.0-cp312-cp312-manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/yarl-1.23.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/setuptools-80.10.2-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/cuda_pathfinder-1.5.4-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/sentry_sdk-2.58.0-py2.py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/aiohttp-3.13.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/rpds_py-0.30.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/quack_kernels-0.4.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/jmespath-1.1.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/astor-0.8.1-py2.py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/sympy-1.14.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/mdurl-0.1.2-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/packaging-26.2-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pygments-2.20.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/lm_format_enforcer-0.11.3-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/llguidance-1.3.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opentelemetry_exporter_otlp_proto_http-1.41.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cudnn_frontend-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/typer-0.25.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/filelock-3.29.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/rich-15.0.0-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/fastapi_cli-0.0.24-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/transformers-4.57.6-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/importlib_metadata-8.7.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opentelemetry_exporter_otlp-1.41.1-py3-none-any.whl
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/fastapi-0.136.1-py3-none-any.whl
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/setup_commands.json
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/deploy_target.pkl
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/preamble.txt
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/teardown_commands.json
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/git_status.txt
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/README.dataset.md
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/taaf-kaggle-bundle.json
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/benchmark_initial.pkl
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/Makefile
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/pyproject.toml
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/README.md
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/uv.lock
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/scripts/pull_kaggle_runs.sh
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/scripts/ensure_server_api_key.sh
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/scripts/server_curl.sh
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/scripts/reorganize_runs.sh
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/configs/inference.openrouter.json
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/configs/significance.json
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/configs/eval.json
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/configs/inference.json
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/viewer/data.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/viewer/server.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/viewer/__init__.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/viewer/index.html
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/__init__.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/utils/openai_compat.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/utils/run_artifacts.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/utils/viewer_artifacts.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/utils/segmentation.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/utils/animation.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/utils/__init__.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/utils/grid_utils.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/agent/runtime_state.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/agent/vision_context.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/agent/action_names.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/agent/prompts.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/agent/__init__.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/agent/noop_guard.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/agent/tool_agent.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/agent/python_tool_sandbox.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/tools/eval_plot.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/tools/traces.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/tools/vllm_runtime_lora_guard.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/tools/eval.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/tools/significance.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/tools/config_value.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/tools/chat.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/tools/__init__.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/framework/run.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/framework/kaggle.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/framework/__init__.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/ARC3-Inference/inference/framework/solver.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/Makefile
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/pyproject.toml
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/README.md
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/uv.lock
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/scripts/refresh_examples.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/src/taaf/diagnostics.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/src/taaf/game_api.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/src/taaf/standard_benchmarks.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/src/taaf/kaggle_random.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/src/taaf/benchmark.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/src/taaf/solver_examples.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/src/taaf/deploy_inline.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/src/taaf/deploy.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/src/taaf/game_examples.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/src/taaf/game.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/src/taaf/deploy_kaggle.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/src/taaf/deploy_slurm.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/src/taaf/support.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/src/taaf/__init__.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/src/taaf/solver.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/src/taaf/competition_arcade.py
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/src/taaf/kaggle/taaf_kaggle_run_share.ipynb
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim/src/tufa-arc-agi-framework/src/taaf/kaggle/taaf_kaggle_run.ipynb
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/model.safetensors.index.json
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/model-layers-00008-of-00016.safetensors
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/model-layers-00007-of-00016.safetensors
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/config.json
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/merges.txt
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/outside.safetensors
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/model-layers-00010-of-00016.safetensors
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/model-layers-00013-of-00016.safetensors
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/model-layers-00002-of-00016.safetensors
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/LICENSE
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/model-layers-00014-of-00016.safetensors
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/model-layers-00016-of-00016.safetensors
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/preprocessor_config.json
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/video_preprocessor_config.json
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/README.md
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/tokenizer.json
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/vocab.json
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/model-layers-00004-of-00016.safetensors
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/tokenizer_config.json
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/model-layers-00009-of-00016.safetensors
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/model-layers-00005-of-00016.safetensors
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/mtp.safetensors
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/chat_template.jinja
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/model-layers-00001-of-00016.safetensors
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/model-layers-00006-of-00016.safetensors
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/model-layers-00011-of-00016.safetensors
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/.gitattributes
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/model-layers-00003-of-00016.safetensors
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/model-layers-00012-of-00016.safetensors
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/model-layers-00015-of-00016.safetensors
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1/generation_config.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/sk48/d8078629/sk48.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/sk48/d8078629/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/tn36/ef4dde99/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/tn36/ef4dde99/tn36.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/m0r0/492f87ba/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/m0r0/492f87ba/m0r0.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/bp35/0a0ad940/bp35.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/bp35/0a0ad940/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/cn04/2fe56bfb/cn04.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/cn04/2fe56bfb/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/dc22/fdcac232/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/dc22/fdcac232/dc22.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/tu93/0768757b/tu93.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/tu93/0768757b/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/lp85/305b61c3/lp85.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/lp85/305b61c3/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/ka59/38d34dbb/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/ka59/38d34dbb/ka59.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/wa30/ee6fef47/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/wa30/ee6fef47/wa30.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/vc33/5430563c/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/vc33/5430563c/vc33.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/lf52/271a04aa/lf52.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/lf52/271a04aa/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/r11l/495a7899/r11l.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/r11l/495a7899/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/sc25/635fd71a/sc25.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/sc25/635fd71a/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/sp80/589a99af/sp80.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/sp80/589a99af/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/ar25/0c556536/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/ar25/0c556536/ar25.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/sb26/7fbdac44/sb26.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/sb26/7fbdac44/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/cd82/fb555c5d/cd82.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/cd82/fb555c5d/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/re86/8af5384d/re86.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/re86/8af5384d/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/s5i5/18d95033/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/s5i5/18d95033/s5i5.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/ls20/9607627b/ls20.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/ls20/9607627b/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/ft09/0d8bbf25/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/ft09/0d8bbf25/ft09.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/su15/1944f8ab/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/su15/1944f8ab/su15.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/tr87/cd924810/tr87.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/tr87/cd924810/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/g50t/5849a774/g50t.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/environment_files/g50t/5849a774/metadata.json
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.pre-commit-config.yaml
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/pytest.ini
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/LICENSE
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.gitignore
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/main.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/pyproject.toml
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/llms.txt
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/README.md
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/uv.lock
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.env.example
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.python-version
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/tests/conftest.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/tests/README.md
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/tests/__init__.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/tests/unit/test_core.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/tests/unit/test_recorder.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/tests/unit/test_swarm.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/recorder.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/agent.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/README.md
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/swarm.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/tracing.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/__init__.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/templates/smolagents.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/templates/langgraph_random_agent.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/templates/llm_agents.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/templates/multimodal.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/templates/README.md
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/templates/langgraph_functional_agent.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/templates/random_agent.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/templates/reasoning_agent.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/templates/langgraph_thinking/agent.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/templates/langgraph_thinking/tools.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/templates/langgraph_thinking/schema.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/templates/langgraph_thinking/vision.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/templates/langgraph_thinking/prompts.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/templates/langgraph_thinking/__init__.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/templates/langgraph_thinking/nodes.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/agents/templates/langgraph_thinking/llm.py
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/config
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/packed-refs
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/HEAD
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/index
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/description
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/info/exclude
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/refs/heads/main
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/refs/remotes/origin/HEAD
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/hooks/pre-merge-commit.sample
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/hooks/prepare-commit-msg.sample
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/hooks/update.sample
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/hooks/pre-push.sample
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/hooks/pre-rebase.sample
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/hooks/pre-applypatch.sample
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/hooks/push-to-checkout.sample
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/hooks/pre-commit.sample
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/hooks/commit-msg.sample
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/hooks/post-update.sample
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/hooks/pre-receive.sample
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/hooks/fsmonitor-watchman.sample
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/hooks/applypatch-msg.sample
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/hooks/sendemail-validate.sample
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/logs/HEAD
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/logs/refs/heads/main
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/logs/refs/remotes/origin/HEAD
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/objects/pack/pack-9e3fcc160aa7f30f497d64a294db91c3b0de5a2c.pack
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/objects/pack/pack-9e3fcc160aa7f30f497d64a294db91c3b0de5a2c.idx
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/ARC-AGI-3-Agents/.git/objects/pack/pack-9e3fcc160aa7f30f497d64a294db91c3b0de5a2c.rev
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/typing_extensions-4.15.0-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/packaging-26.1-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/pyparsing-3.3.2-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/pydantic-2.13.2-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/werkzeug-3.1.8-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/arc_agi-0.9.8-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/typing_inspection-0.4.2-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/requests-2.33.1-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/annotated_types-0.7.0-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/cycler-0.12.1-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/itsdangerous-2.2.0-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/jinja2-3.1.6-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/pydantic_core-2.46.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/six-1.17.0-py2.py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/idna-3.11-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/click-8.3.2-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/blinker-1.9.0-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/python_dateutil-2.9.0.post0-py2.py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/python_dotenv-1.2.2-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/urllib3-2.6.3-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/certifi-2026.2.25-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/arcengine-0.9.3-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/flask-3.1.3-py3-none-any.whl
# /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl

# %%
import asyncio
import contextlib
from html import escape
import json
import os
import pickle
import subprocess
import sys
import time
from datetime import datetime, timedelta
from pathlib import Path
from typing import TextIO
from urllib.request import urlopen

try:
    from IPython.display import HTML, display
except ImportError:
    HTML = None
    display = None


def _env_bool(name: str, default: bool = False) -> bool:
    raw = os.getenv(name, "").strip().lower()
    if not raw:
        return default
    return raw in {"1", "true", "yes", "y", "on"}


NOTEBOOK_START_EPOCH = time.time()
RUN_AS_SUBMISSION = False
RUN_AS_SUBMISSION = RUN_AS_SUBMISSION or _env_bool("KAGGLE_IS_COMPETITION_RERUN", False)
ENABLE_GPU = True

os.environ["TAAF_RUN_AS_SUBMISSION"] = "1" if RUN_AS_SUBMISSION else "0"
os.environ.setdefault("MPLBACKEND", "Agg")

if ENABLE_GPU:
    cuda_library_path = "/usr/local/nvidia/lib64"
    existing = [entry for entry in os.environ.get("LIBRARY_PATH", "").split(os.pathsep) if entry]
    os.environ["LIBRARY_PATH"] = os.pathsep.join(
        [cuda_library_path, *[entry for entry in existing if entry != cuda_library_path]]
    )

print(f"TAAF RUN_AS_SUBMISSION={RUN_AS_SUBMISSION}")
if ENABLE_GPU:
    print(f"taaf.kaggle: LIBRARY_PATH={os.environ['LIBRARY_PATH']}")

wheelhouse = Path("/kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels")
if wheelhouse.exists():
    subprocess.check_call(
        [
            sys.executable,
            "-m",
            "pip",
            "install",
            "--no-index",
            "--no-warn-conflicts",
            "--disable-pip-version-check",
            "--find-links",
            str(wheelhouse),
            "arc-agi",
        ]
    )
elif os.getenv("TAAF_KAGGLE_BUNDLE_DIR"):
    print(f"Competition wheelhouse not found at {wheelhouse}; assuming local debug dependencies are installed.")
else:
    raise RuntimeError(f"Competition wheelhouse not found at {wheelhouse}.")
    # Qwen3.8 / Kaggle input configuration
DATASET_SOURCES: list[str] = [
    "jakobbrggen/taaf-kaggle-source-anim-20260807-anim",
    "driessmit1/arc3-vllm-h100-wheelhouse-v3",
]
KERNEL_SOURCES: list[str] = []

# New private Kaggle Model (Version 1).
QWEN_MODEL_OWNER = "foysalemonshanto"
QWEN_MODEL_SLUG = "qwen3-8-27b-fp8-repacked-v1"
QWEN_MODEL_REF = f"{QWEN_MODEL_OWNER}/{QWEN_MODEL_SLUG}"
QWEN_MODEL_VARIATION = "hf-fp8"
QWEN_MODEL_VERSION = "1"
QWEN_SERVED_MODEL_NAME = "Qwen/Qwen3.8-27B-FP8"
QWEN_MODEL_PATH = Path(
    f"/kaggle/input/models/{QWEN_MODEL_OWNER}/{QWEN_MODEL_SLUG}/"
    f"pytorch/{QWEN_MODEL_VARIATION}/{QWEN_MODEL_VERSION}"
)

DATASET_BUNDLE_MARKER = "taaf-kaggle-bundle.json"
WORKING_DIR = Path(os.getenv("TAAF_KAGGLE_WORKING_DIR", "/kaggle/working")).resolve()
SETUP_ENV_PATH = WORKING_DIR / "taaf_setup_env.json"
SOFT_DEADLINE_BUFFER_S = 600.0
WORKING_DIR.mkdir(parents=True, exist_ok=True)

# Keep the whole run offline. vLLM/Transformers must use the mounted files only.
os.environ["HF_HUB_OFFLINE"] = "1"
os.environ["TRANSFORMERS_OFFLINE"] = "1"


def _split_ref(ref: str) -> tuple[str, str]:
    owner, slug = ref.split("/", 1)
    return owner, slug


def _dataset_mount_candidates(ref: str) -> list[Path]:
    owner, slug = _split_ref(ref)
    return [Path("/kaggle/input") / slug, Path("/kaggle/input/datasets") / owner / slug]


def _kernel_mount_candidates(ref: str) -> list[Path]:
    owner, slug = _split_ref(ref)
    return [Path("/kaggle/usr/lib/notebooks") / owner / slug]


def _first_existing(candidates: list[Path]) -> Path | None:
    return next((candidate for candidate in candidates if candidate.exists()), None)


def _find_taaf_bundle() -> Path:
    explicit = os.getenv("TAAF_KAGGLE_BUNDLE_DIR", "").strip()
    if explicit:
        path = Path(explicit)
        if (path / DATASET_BUNDLE_MARKER).is_file():
            return path

    # Prefer the attached bundle whose marker actually exists.
    for root in [Path("/kaggle/input/datasets"), Path("/kaggle/input"), Path.cwd()]:
        if root.exists():
            for marker in root.rglob(DATASET_BUNDLE_MARKER):
                return marker.parent

    raise RuntimeError("Could not find TAAF Kaggle source bundle dataset.")


def _load_setup_env() -> dict[str, str]:
    if not SETUP_ENV_PATH.is_file():
        return {}
    data = json.loads(SETUP_ENV_PATH.read_text(encoding="utf-8"))
    if not isinstance(data, dict):
        raise RuntimeError(f"{SETUP_ENV_PATH} must contain a JSON object.")
    return {str(key): str(value) for key, value in data.items()}


def _write_setup_env_updates(updates: dict[str, str]) -> None:
    data = _load_setup_env()
    data.update(updates)
    SETUP_ENV_PATH.write_text(
        json.dumps(data, indent=2, sort_keys=True) + "\n",
        encoding="utf-8",
    )


BUNDLE_DIR = _find_taaf_bundle()
print(f"TAAF source bundle: {BUNDLE_DIR}")

# Verify the Qwen3.8 Kaggle Model before any expensive setup work starts.
if not QWEN_MODEL_PATH.is_dir():
    raise FileNotFoundError(
        "Qwen3.8 Kaggle Model is not attached.\n"
        f"Expected path:\n{QWEN_MODEL_PATH}\n\n"
        "Attach: Qwen3.8 27B FP8 Repacked → PyTorch → hf-fp8 → Version 1"
    )

_required_qwen_files = [
    "config.json",
    "model.safetensors.index.json",
    "tokenizer.json",
    "tokenizer_config.json",
    "outside.safetensors",
    "mtp.safetensors",
    "chat_template.jinja",
]
_missing_qwen_files = [
    name for name in _required_qwen_files if not (QWEN_MODEL_PATH / name).is_file()
]
if _missing_qwen_files:
    raise FileNotFoundError(
        "Qwen3.8 mount is incomplete; missing: " + ", ".join(_missing_qwen_files)
    )

_qwen_layer_shards = sorted(QWEN_MODEL_PATH.glob("model-layers-*.safetensors"))
_qwen_safetensors = sorted(QWEN_MODEL_PATH.glob("*.safetensors"))
if len(_qwen_layer_shards) != 16 or len(_qwen_safetensors) != 18:
    raise RuntimeError(
        "Unexpected Qwen3.8 checkpoint layout: "
        f"{len(_qwen_layer_shards)} layer shards, "
        f"{len(_qwen_safetensors)} safetensors files."
    )

# Tell setup commands and solver code where Kaggle mounted every attached input.
kaggle_input_paths: dict[str, str] = {}
for index, ref in enumerate(DATASET_SOURCES):
    candidates = _dataset_mount_candidates(ref)
    resolved = BUNDLE_DIR if index == 0 else _first_existing(candidates)
    kaggle_input_paths[ref] = str(resolved or candidates[0])

for ref in KERNEL_SOURCES:
    candidates = _kernel_mount_candidates(ref)
    kaggle_input_paths[ref] = str(_first_existing(candidates) or candidates[0])

# The bundled setup resolver asks for owner/slug. Give it a model ref that maps
# directly to the full Kaggle Model version directory.
kaggle_input_paths[QWEN_MODEL_REF] = str(QWEN_MODEL_PATH)

setup_env = {
    "TAAF_KAGGLE_INPUT_PATHS": json.dumps(kaggle_input_paths, sort_keys=True),
    "TAAF_KAGGLE_DATASET_SOURCES": json.dumps(DATASET_SOURCES),
    "TAAF_KAGGLE_KERNEL_SOURCES": json.dumps(KERNEL_SOURCES),
    "TAAF_QWEN_MODEL_REF": QWEN_MODEL_REF,
    "TAAF_QWEN_MODEL_PATH": str(QWEN_MODEL_PATH),
    "TAAF_QWEN_SERVED_MODEL_NAME": QWEN_SERVED_MODEL_NAME,
    "HF_HUB_OFFLINE": "1",
    "TRANSFORMERS_OFFLINE": "1",
}
os.environ.update(setup_env)
_write_setup_env_updates(setup_env)

print("\n✅ Qwen3.8 input configuration ready")
print(f"Model ref:       {QWEN_MODEL_REF}")
print(f"Physical path:   {QWEN_MODEL_PATH}")
print(f"Served model:    {QWEN_SERVED_MODEL_NAME}")
print(f"Safetensors:     {len(_qwen_safetensors)}")
print(f"Layer shards:    {len(_qwen_layer_shards)}")
print(f"TAAF input map:  {setup_env['TAAF_KAGGLE_INPUT_PATHS']}")

# Audit the attached inputs that matter for this run.
print("=== TAAF bundle ===")
print(BUNDLE_DIR)
print("Exists:", BUNDLE_DIR.exists())

print("\n=== vLLM wheelhouse ===")
_vllm_wheelhouse = Path(
    "/kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3"
)
print(_vllm_wheelhouse)
print("Exists:", _vllm_wheelhouse.exists())

print("\n=== Qwen3.8 Kaggle Model ===")
print(QWEN_MODEL_PATH)
print("Exists:", QWEN_MODEL_PATH.exists())
print("Safetensors:", len(list(QWEN_MODEL_PATH.glob("*.safetensors"))))
print(
    "Repacked layer shards:",
    len(list(QWEN_MODEL_PATH.glob("model-layers-*.safetensors"))),
)

import re


def _source_path_entries(bundle_dir: Path) -> list[Path]:
    src_root = bundle_dir / "src"
    if not src_root.is_dir():
        return []

    entries: list[Path] = []
    for repo in sorted(src_root.iterdir(), reverse=True):
        if not repo.is_dir():
            continue
        for candidate in (repo / "src", repo):
            if candidate.is_dir():
                entries.append(candidate)
    return entries


def _command_env() -> dict[str, str]:
    env = os.environ.copy()
    env["PYTHON"] = sys.executable
    env["TAAF_KAGGLE_BUNDLE_DIR"] = str(BUNDLE_DIR)
    env["TAAF_KAGGLE_WORKING_DIR"] = str(WORKING_DIR)
    env["TAAF_KAGGLE_SETUP_ENV"] = str(SETUP_ENV_PATH)
    env["HF_HUB_OFFLINE"] = "1"
    env["TRANSFORMERS_OFFLINE"] = "1"
    env.update(_load_setup_env())
    return env


def _replace_python_assignment(
    command: str,
    variable_name: str,
    value: str,
) -> tuple[str, int]:
    """Replace a top-level Python string assignment inside the setup here-doc."""
    pattern = rf"(?m)^{re.escape(variable_name)}\s*=\s*(['\"])[^\r\n]*?\1\s*$"
    replacement = f"{variable_name} = {value!r}"
    return re.subn(pattern, replacement, command, count=1)


def _patch_qwen38_setup_commands(commands: list[str]) -> list[str]:
    """
    Preserve the TAAF deployment setup but replace its model identity with the
    Qwen3.8 Kaggle Model. This avoids copying/forking the large bundled setup
    script and keeps the wheelhouse/GPU/vLLM behavior from the source bundle.
    """
    patched: list[str] = []
    replacement_counts = {
        "MODEL_OWNER": 0,
        "MODEL_SLUG": 0,
        "SERVED_MODEL_NAME": 0,
    }

    replacements = {
        "MODEL_OWNER": QWEN_MODEL_OWNER,
        "MODEL_SLUG": QWEN_MODEL_SLUG,
        "SERVED_MODEL_NAME": QWEN_SERVED_MODEL_NAME,
    }

    for raw_command in commands:
        command = str(raw_command)

        for variable_name, value in replacements.items():
            command, count = _replace_python_assignment(
                command,
                variable_name,
                value,
            )
            replacement_counts[variable_name] += count

        # Make offline behavior explicit in the child process as well.
        if "def vllm_env()" in command:
            command = command.replace(
                "'VLLM_NO_USAGE_STATS': '1',",
                "'VLLM_NO_USAGE_STATS': '1',\n"
                "            'HF_HUB_OFFLINE': '1',\n"
                "            'TRANSFORMERS_OFFLINE': '1',",
                1,
            )

        patched.append(command)

    missing = [
        name for name, count in replacement_counts.items() if count == 0
    ]
    if missing:
        raise RuntimeError(
            "Could not update the bundled TAAF setup for Qwen3.8. "
            "Missing assignment(s): "
            + ", ".join(missing)
            + ". The attached TAAF bundle's setup_commands.json has changed."
        )

    print("taaf.kaggle: Qwen3.8 setup patch =", replacement_counts, flush=True)
    return patched


def _run_shell_commands(filename: str, *, label: str, check: bool) -> None:
    path = BUNDLE_DIR / filename
    if not path.is_file():
        return

    commands = json.loads(path.read_text(encoding="utf-8"))
    if not isinstance(commands, list):
        raise RuntimeError(f"{path} must contain a JSON list of shell commands.")

    if filename == "setup_commands.json":
        commands = _patch_qwen38_setup_commands(commands)

    env = _command_env()
    for command in commands:
        print(f"taaf.kaggle: {label} command: {command}", flush=True)
        result = subprocess.run(
            str(command),
            shell=True,
            check=check,
            cwd=WORKING_DIR,
            env=env,
        )
        if not check and result.returncode != 0:
            print(
                f"taaf.kaggle: {label} command exited with {result.returncode}",
                flush=True,
            )

        # Setup commands may export additional runtime settings.
        env.update(_load_setup_env())
        os.environ.update(env)


# Make bundled TAAF repos importable for this notebook and child Python processes.
source_entries = _source_path_entries(BUNDLE_DIR)
for entry in source_entries:
    if str(entry) not in sys.path:
        sys.path.insert(0, str(entry))

if source_entries:
    import sysconfig

    pth_path = Path(sysconfig.get_paths()["purelib"]) / "taaf_kaggle_sources.pth"
    pth_path.write_text(
        "".join(f"{entry}\n" for entry in source_entries),
        encoding="utf-8",
    )
    print(
        f"taaf.kaggle: wrote {pth_path} ({len(source_entries)} source roots)",
        flush=True,
    )

# Run the TAAF deployment setup, patched to use Qwen3.8.
_run_shell_commands("setup_commands.json", label="setup", check=True)

# Setup commands may export PYTHONPATH through TAAF_KAGGLE_SETUP_ENV.
pythonpath_entries = [
    entry for entry in os.environ.get("PYTHONPATH", "").split(os.pathsep) if entry
]
for entry in reversed(pythonpath_entries):
    if entry not in sys.path:
        sys.path.insert(0, entry)

# Fail early if the analyzer is still exposing an old model identity.
_actual_model_id = os.environ.get("INFERENCE_ANALYZER_MODEL", "")
if _actual_model_id != QWEN_SERVED_MODEL_NAME:
    raise RuntimeError(
        "TAAF setup completed, but the analyzer model ID is wrong: "
        f"{_actual_model_id!r}; expected {QWEN_SERVED_MODEL_NAME!r}"
    )

print("\n✅ TAAF/vLLM setup completed for Qwen3.8")
print("Model path:", QWEN_MODEL_PATH)
print("Analyzer model:", _actual_model_id)
print("Analyzer endpoint:", os.environ.get("LOCAL_ANALYZER_BASE_URL"))

def _soft_end_time(max_runtime_s: float, *, run_as_submission: bool) -> datetime | None:
    if run_as_submission or max_runtime_s <= 0:
        return None
    budget = max(1.0, max_runtime_s)
    buffer = min(SOFT_DEADLINE_BUFFER_S, budget / 2)
    start = datetime.fromtimestamp(NOTEBOOK_START_EPOCH)
    return start + timedelta(seconds=budget - buffer)


def _competition_games():
    import arc_agi

    import taaf.game_api

    spec = taaf.game_api.ArcadeSpec(
        operation_mode=arc_agi.OperationMode.COMPETITION,
        arc_base_url=os.environ.get("ARC_BASE_URL", "http://gateway:8001/"),
        environments_dir="",
    )
    arcade = arc_agi.Arcade(
        operation_mode=arc_agi.OperationMode.COMPETITION,
        arc_base_url=spec.arc_base_url,
        environments_dir="",
    )
    game_ids = [env_info.game_id for env_info in arcade.available_environments]
    if not game_ids:
        raise RuntimeError("Competition Arcade exposed zero environments.")
    return [taaf.game_api.GameAPI(env_name=game_id, arcade_spec=spec) for game_id in game_ids]


@contextlib.contextmanager
def _tee_to_file(log_path: Path):
    log_path.parent.mkdir(parents=True, exist_ok=True)
    log_file = open(log_path, "w", buffering=1)
    original_stdout = sys.stdout
    original_stderr = sys.stderr
    sys.stdout = _Tee(original_stdout, log_file)
    sys.stderr = _Tee(original_stderr, log_file)
    try:
        yield
    finally:
        sys.stdout = original_stdout
        sys.stderr = original_stderr
        log_file.close()


class _Tee:
    def __init__(self, *streams: TextIO) -> None:
        self._streams = streams

    def write(self, data: str) -> int:
        n = 0
        for stream in self._streams:
            n = stream.write(data)
        return n

    def flush(self) -> None:
        for stream in self._streams:
            stream.flush()

    def isatty(self) -> bool:
        return any(getattr(stream, "isatty", lambda: False)() for stream in self._streams)


true_submission = _env_bool("KAGGLE_IS_COMPETITION_RERUN", False)
run_as_submission = _env_bool("TAAF_RUN_AS_SUBMISSION", False) or true_submission
os.environ["ONLY_RESET_LEVELS"] = "true"
os.environ["TAAF_RUN_AS_SUBMISSION"] = "1" if run_as_submission else "0"
os.environ["TAAF_MINIMAL_DIAGNOSTICS"] = "1" if run_as_submission else "0"

with open(BUNDLE_DIR / "deploy_target.pkl", "rb") as file:
    target = pickle.load(file)
target.actual_run_as_submission = run_as_submission
target.is_competition_rerun = true_submission
soft_end = _soft_end_time(float(getattr(target, "max_runtime_s", 0.0) or 0.0), run_as_submission=run_as_submission)

with open(BUNDLE_DIR / "benchmark_initial.pkl", "rb") as file:
    bm = pickle.load(file)
bm.job_dir = WORKING_DIR

# Inline customization hook — Q38 P1-style public evaluation.
#
# Q38 P1 runs the full 25 public ARC-AGI-3 games once each (25 games × 1 pass).
# This override applies only to the public/offline notebook run. Competition reruns
# still replace bm.games from Kaggle's live gateway in the final run cell.

print("Benchmark analyzer model:", os.environ.get("INFERENCE_ANALYZER_MODEL"))
print("Qwen3.8 model path:", os.environ.get("TAAF_QWEN_MODEL_PATH"))

Q38_P1_PUBLIC_GAME_IDS = [
    "ar25-0c556536",
    "bp35-0a0ad940",
    "cd82-fb555c5d",
    "cn04-2fe56bfb",
    "dc22-fdcac232",
    "ft09-0d8bbf25",
    "g50t-5849a774",
    "ka59-38d34dbb",
    "lf52-271a04aa",
    "lp85-305b61c3",
    "ls20-9607627b",
    "m0r0-492f87ba",
    "r11l-495a7899",
    "re86-8af5384d",
    "s5i5-18d95033",
    "sb26-7fbdac44",
    "sc25-635fd71a",
    "sk48-d8078629",
    "sp80-589a99af",
    "su15-1944f8ab",
    "tn36-ef4dde99",
    "tr87-cd924810",
    "tu93-0768757b",
    "vc33-5430563c",
    "wa30-ee6fef47",
]

if not true_submission:
    if len(Q38_P1_PUBLIC_GAME_IDS) != 25 or len(set(Q38_P1_PUBLIC_GAME_IDS)) != 25:
        raise RuntimeError("Q38 P1 public game list must contain exactly 25 unique games.")
    if not bm.games:
        raise RuntimeError("benchmark_initial.pkl contains no template public game.")

    import taaf.game_api

    template_game = bm.games[0]
    arcade_spec = getattr(template_game, "arcade_spec", None)
    if arcade_spec is None:
        arcade_spec = getattr(template_game, "_arcade_spec", None)
    if arcade_spec is None:
        raise RuntimeError(
            "Could not recover the public ArcadeSpec from benchmark_initial.pkl; "
            "cannot construct the 25-game Q38 P1 evaluation set."
        )

    bm.games = [
        taaf.game_api.GameAPI(env_name=game_id, arcade_spec=arcade_spec)
        for game_id in Q38_P1_PUBLIC_GAME_IDS
    ]
    bm.n_passes = 1
    bm.game_weights = None

    # These already match Q38 P1 in the source notebook; set them explicitly so the
    # intended evaluation configuration is visible and stable.
    if hasattr(bm.solver, "concurrency"):
        bm.solver.concurrency = 28
    if hasattr(bm.solver, "max_runtime_s_per_game"):
        bm.solver.max_runtime_s_per_game = 7920.0

    bm.label = f"{bm.label}-25g-p1"
    print(f"Public evaluation override: {len(bm.games)} games × {bm.n_passes} pass = {len(bm.games) * bm.n_passes} runs")
    print("Public evaluation concurrency:", getattr(bm.solver, "concurrency", None))
    print("Public per-game runtime cap (s):", getattr(bm.solver, "max_runtime_s_per_game", None))

run_context = contextlib.nullcontext() if run_as_submission else _tee_to_file(WORKING_DIR / "stdout.log")
with run_context:
    preamble = (BUNDLE_DIR / "preamble.txt").read_text(encoding="utf-8")
    print(preamble)
    print(f"deploy.kaggle: working_dir             = {WORKING_DIR}")
    print(f"deploy.kaggle: run_as_submission       = {run_as_submission}")
    print(f"deploy.kaggle: competition_rerun       = {true_submission}")
    print(f"deploy.kaggle: soft_end_time           = {soft_end}")
    print("---")

    bundled_git_status = BUNDLE_DIR / "git_status.txt"
    if bundled_git_status.is_file():
        (WORKING_DIR / "git_status.txt").write_text(
            bundled_git_status.read_text(encoding="utf-8"),
            encoding="utf-8",
        )

    if true_submission:
        # Competition reruns use Kaggle's live gateway instead of the bundled offline games.
        os.environ.setdefault("ARC_API_KEY", "test-key-123")
        os.environ.setdefault("ARC_BASE_URL", "http://gateway:8001/")
        os.environ.setdefault("SCHEME", "http")
        os.environ.setdefault("HOST", "gateway")
        os.environ.setdefault("PORT", "8001")
        os.environ.setdefault("OPERATION_MODE", "competition")
        os.environ.setdefault("ENVIRONMENTS_DIR", "")
        os.environ.setdefault("RECORDINGS_DIR", str(WORKING_DIR / "server_recording"))

        deadline = time.monotonic() + 600.0
        last_error = ""
        while time.monotonic() < deadline:
            try:
                with urlopen("http://gateway:8001/api/games", timeout=10) as response:
                    if response.status < 500:
                        break
            except Exception as exc:
                last_error = repr(exc)
            time.sleep(5)
        else:
            raise RuntimeError(f"Kaggle gateway did not become ready: {last_error}")

        bm.games = _competition_games()
        bm.n_passes = 1
        bm.game_weights = None

    async def _execute_benchmark() -> None:
        await bm.run(
            soft_end_time=soft_end,
            runtime_environment=target,
            minimal_diagnostics=run_as_submission,
        )

    def _run_async_task(coro) -> None:
        try:
            loop = asyncio.get_running_loop()
        except RuntimeError:
            loop = None

        if loop is not None and loop.is_running():
            try:
                import nest_asyncio
                nest_asyncio.apply()
                loop.run_until_complete(coro)
            except Exception:
                import concurrent.futures
                with concurrent.futures.ThreadPoolExecutor(max_workers=1) as pool:
                    pool.submit(asyncio.run, coro).result()
        else:
            asyncio.run(coro)

    try:
        _run_async_task(_execute_benchmark())
        if not true_submission and Path("/kaggle/input").exists():
            try:
                import pandas as pd

                submission = pd.DataFrame(
                    data=[["1_0", "1", True, 1]],
                    columns=["row_id", "game_id", "end_of_game", "score"],
                )
                submission.to_parquet(WORKING_DIR / "submission.parquet", index=False)
            except Exception as exc:
                print(f"taaf.kaggle: could not write offline dummy submission: {exc!r}", flush=True)
    finally:
        _run_shell_commands("teardown_commands.json", label="teardown", check=False)

diagnostics_html = WORKING_DIR / "diagnostics.html"
if diagnostics_html.is_file():
    if display is not None and HTML is not None:
        # Isolate the full document in an iframe so its styles don't leak into the notebook.
        display(
            HTML(
                f'<iframe srcdoc="{escape(diagnostics_html.read_text(encoding="utf-8"), quote=True)}" '
                'width="100%" height="900" style="border:0"></iframe>'
            )
        )
    else:
        print(f"Diagnostics written to {diagnostics_html}")
else:
    print("No diagnostics.html — minimal diagnostics (real submission) suppresses it.")
# Out:
# TAAF RUN_AS_SUBMISSION=False
# taaf.kaggle: LIBRARY_PATH=/usr/local/nvidia/lib64:/usr/local/cuda/lib64/stubs
# Looking in links: /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels
# Processing /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/arc_agi-0.9.8-py3-none-any.whl
# Processing /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/arcengine-0.9.3-py3-none-any.whl (from arc-agi)
# Requirement already satisfied: flask>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from arc-agi) (3.1.3)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from arc-agi) (3.10.0)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from arc-agi) (2.12.3)
# Requirement already satisfied: python-dotenv>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from arc-agi) (1.2.2)
# Processing /kaggle/input/competitions/arc-prize-2026-arc-agi-3/arc_agi_3_wheels/pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (from arc-agi)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from arc-agi) (2.32.4)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from arcengine>=0.9.3->arc-agi) (2.0.2)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask>=3.1.0->arc-agi) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from flask>=3.1.0->arc-agi) (8.3.3)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask>=3.1.0->arc-agi) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from flask>=3.1.0->arc-agi) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask>=3.1.0->arc-agi) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from flask>=3.1.0->arc-agi) (3.1.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->arc-agi) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->arc-agi) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->arc-agi) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->arc-agi) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->arc-agi) (26.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->arc-agi) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->arc-agi) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->arc-agi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->arc-agi) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->arc-agi) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->arc-agi) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->arc-agi) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->arc-agi) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->arc-agi) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->arc-agi) (2026.4.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->arc-agi) (1.17.0)
# Installing collected packages: pillow, arcengine, arc-agi
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
# Successfully installed arc-agi-0.9.8 arcengine-0.9.3 pillow-12.2.0
# TAAF source bundle: /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim
#
# ✅ Qwen3.8 input configuration ready
# Model ref:       foysalemonshanto/qwen3-8-27b-fp8-repacked-v1
# Physical path:   /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1
# Served model:    Qwen/Qwen3.8-27B-FP8
# Safetensors:     18
# Layer shards:    16
# TAAF input map:  {"driessmit1/arc3-vllm-h100-wheelhouse-v3": "/kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3", "foysalemonshanto/qwen3-8-27b-fp8-repacked-v1": "/kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1", "jakobbrggen/taaf-kaggle-source-anim-20260807-anim": "/kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim"}
# === TAAF bundle ===
# /kaggle/input/datasets/jakobbrggen/taaf-kaggle-source-anim-20260807-anim
# Exists: True
#
# === vLLM wheelhouse ===
# /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3
# Exists: True
#
# === Qwen3.8 Kaggle Model ===
# /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1
# Exists: True
# Safetensors: 18
# Repacked layer shards: 16
# taaf.kaggle: wrote /usr/local/lib/python3.12/dist-packages/taaf_kaggle_sources.pth (3 source roots)
# taaf.kaggle: Qwen3.8 setup patch = {'MODEL_OWNER': 1, 'MODEL_SLUG': 1, 'SERVED_MODEL_NAME': 1}
# taaf.kaggle: setup command: "$PYTHON" - <<'PYSETUP'
# import json
# import os
# import shutil
# import subprocess
# import sys
# import time
# import urllib.request
# from pathlib import Path
#
# WHEELHOUSE_OWNER = 'driessmit1'
# WHEELHOUSE_SLUG = 'arc3-vllm-h100-wheelhouse-v3'
# MODEL_OWNER = 'foysalemonshanto'
# MODEL_SLUG = 'qwen3-8-27b-fp8-repacked-v1'
# SERVED_MODEL_NAME = 'Qwen/Qwen3.8-27B-FP8'
# VLLM_HOST = '127.0.0.1'
# VLLM_PORT = 1234
# VLLM_BASE_URL = f'http://{VLLM_HOST}:{VLLM_PORT}/v1'
# VLLM_MAX_MODEL_LEN = 65536
# ANALYZER_CONTEXT_WINDOW = 32768
# VLLM_TENSOR_PARALLEL_SIZE = 1
# WORKING_DIR = Path(os.environ['TAAF_KAGGLE_WORKING_DIR'])
# SITE_PACKAGES = WORKING_DIR / 'vllm-site-packages'
# VLLM_SERVER_LOG = WORKING_DIR / 'vllm-openai-server.log'
# VLLM_SERVER_PID = WORKING_DIR / 'vllm-openai-server.pid'
# INSTALL_STAMP = SITE_PACKAGES / f'.{WHEELHOUSE_SLUG}'
# STAMP_TEXT = 'vllm==0.19.0 torch==2.10.0 flashinfer==0.6.6\n'
#
# GPU_NAME_PATTERNS = {'rtx-pro-6000': ('rtx pro 6000',), 'h100': ('h100',), 'l4': ('l4',)}
#
#
# def taaf_kaggle_input_paths() -> dict[str, Path]:
#     raw = os.getenv('TAAF_KAGGLE_INPUT_PATHS', '').strip()
#     if not raw:
#         return {}
#     data = json.loads(raw)
#     if not isinstance(data, dict):
#         raise RuntimeError('TAAF_KAGGLE_INPUT_PATHS must contain a JSON object.')
#     return {str(ref): Path(str(path)) for ref, path in data.items()}
#
#
# def resolve_kaggle_dataset_path(owner: str, slug: str) -> Path:
#     mapped = taaf_kaggle_input_paths().get(f'{owner}/{slug}')
#     if mapped is not None:
#         return mapped
#     for dataset_path in (Path('/kaggle/input') / slug, Path('/kaggle/input/datasets') / owner / slug):
#         if dataset_path.exists():
#             return dataset_path
#     return Path('/kaggle/input') / slug
#
#
# WHEELHOUSE = resolve_kaggle_dataset_path(WHEELHOUSE_OWNER, WHEELHOUSE_SLUG)
# MODEL_PATH = resolve_kaggle_dataset_path(MODEL_OWNER, MODEL_SLUG)
#
#
# def assert_expected_cuda_gpu() -> None:
#     if not Path('/kaggle/input').exists():
#         return
#     assert shutil.which('nvidia-smi'), 'CUDA GPU check failed: nvidia-smi is not available.'
#     result = subprocess.run(['nvidia-smi', '--query-gpu=name', '--format=csv,noheader'], capture_output=True, text=True)
#     assert result.returncode == 0, f'nvidia-smi failed: {result.stderr.strip()}'
#     gpu_names = [line.strip() for line in result.stdout.splitlines() if line.strip()]
#     assert gpu_names, 'nvidia-smi did not report any CUDA GPUs.'
#     expected_gpu_type = os.getenv('KAGGLE_GPU_TYPE', 'rtx-pro-6000').strip().lower()
#     expected_count = os.getenv('KAGGLE_GPU_COUNT', '1')
#     if expected_count.isdigit():
#         assert len(gpu_names) == int(expected_count), f'Expected {expected_count} CUDA GPU(s), found {gpu_names}'
#     patterns = GPU_NAME_PATTERNS.get(expected_gpu_type, (expected_gpu_type.replace('-', ' '),))
#     mismatched = [name for name in gpu_names if not any(pattern in name.lower() for pattern in patterns)]
#     assert not mismatched, f'Expected GPU type {expected_gpu_type!r}, found {gpu_names}'
#     print(f'CUDA GPU check passed for {expected_gpu_type} x{expected_count}: {gpu_names}', flush=True)
#
#
# def vllm_env() -> dict[str, str]:
#     env = os.environ.copy()
#     existing = env.get('PYTHONPATH', '')
#     env['PYTHONPATH'] = str(SITE_PACKAGES) if not existing else f'{SITE_PACKAGES}{os.pathsep}{existing}'
#     env.update(
#         {
#             'USE_TF': '0',
#             'TRANSFORMERS_NO_TF': '1',
#             'TRANSFORMERS_NO_TORCHVISION': '1',
#             'VLLM_NO_USAGE_STATS': '1',
#             'HF_HUB_OFFLINE': '1',
#             'TRANSFORMERS_OFFLINE': '1',
#         }
#     )
#     return env
#
#
# def cached_install_is_usable() -> bool:
#     if not INSTALL_STAMP.exists() or INSTALL_STAMP.read_text(encoding='utf-8') != STAMP_TEXT:
#         return False
#     result = subprocess.run(
#         [sys.executable, '-c', "import vllm, torch; print(f'Cached vLLM {vllm.__version__}, torch {torch.__version__}')"],
#         env=vllm_env(),
#         text=True,
#     )
#     return result.returncode == 0
#
#
# def install_vllm_wheelhouse() -> None:
#     requirements = WHEELHOUSE / 'requirements.lock'
#     if not requirements.exists():
#         raise FileNotFoundError(f'Missing wheelhouse lock file: {requirements}')
#     if cached_install_is_usable():
#         print(f'Using cached vLLM target install at {SITE_PACKAGES}', flush=True)
#         return
#     shutil.rmtree(SITE_PACKAGES, ignore_errors=True)
#     SITE_PACKAGES.mkdir(parents=True, exist_ok=True)
#     cmd = [
#         sys.executable,
#         '-m',
#         'pip',
#         'install',
#         '--no-index',
#         '--find-links',
#         str(WHEELHOUSE),
#         '--requirement',
#         str(requirements),
#         '--target',
#         str(SITE_PACKAGES),
#         '--upgrade',
#         '--ignore-installed',
#         '--only-binary',
#         ':all:',
#         '--no-compile',
#         '--disable-pip-version-check',
#         '--no-warn-conflicts',
#     ]
#     print('Installing vLLM wheelhouse into', SITE_PACKAGES, flush=True)
#     subprocess.run(cmd, check=True)
#     INSTALL_STAMP.write_text(STAMP_TEXT, encoding='utf-8')
#
#
# def request_json(url: str, payload: dict | None = None, timeout: int = 30) -> dict:
#     data = None if payload is None else json.dumps(payload).encode('utf-8')
#     request = urllib.request.Request(url, data=data, headers={'Content-Type': 'application/json'})
#     with urllib.request.urlopen(request, timeout=timeout) as response:
#         return json.loads(response.read().decode('utf-8'))
#
#
# def tail_server_log(lines: int = 80) -> str:
#     if not VLLM_SERVER_LOG.exists():
#         return ''
#     return '\n'.join(VLLM_SERVER_LOG.read_text(encoding='utf-8', errors='replace').splitlines()[-lines:])
#
#
# def wait_for_vllm_server(timeout_seconds: int = 900) -> None:
#     deadline = time.monotonic() + timeout_seconds
#     url = f'{VLLM_BASE_URL}/models'
#     while time.monotonic() < deadline:
#         if VLLM_SERVER_PID.exists():
#             try:
#                 os.kill(int(VLLM_SERVER_PID.read_text().strip()), 0)
#             except OSError as exc:
#                 raise RuntimeError(f'vLLM server process is not alive: {exc}\n{tail_server_log()}') from exc
#         try:
#             models = request_json(url, timeout=5)
#             print('vLLM server ready:', models, flush=True)
#             return
#         except Exception:
#             time.sleep(5)
#     raise TimeoutError(f'Timed out waiting for vLLM server at {url}.\nLast server log lines:\n{tail_server_log()}')
#
#
# def start_vllm_server() -> None:
#     install_vllm_wheelhouse()
#     VLLM_SERVER_LOG.parent.mkdir(parents=True, exist_ok=True)
#     VLLM_SERVER_PID.unlink(missing_ok=True)
#     log_handle = VLLM_SERVER_LOG.open('w', encoding='utf-8')
#     cmd = [
#         sys.executable,
#         '-m',
#         'vllm.entrypoints.openai.api_server',
#         '--model',
#         str(MODEL_PATH),
#         '--served-model-name',
#         SERVED_MODEL_NAME,
#         '--host',
#         VLLM_HOST,
#         '--port',
#         str(VLLM_PORT),
#         '--tensor-parallel-size',
#         str(VLLM_TENSOR_PARALLEL_SIZE),
#         '--enable-auto-tool-choice',
#         '--tool-call-parser',
#         'qwen3_coder',
#         '--generation-config',
#         'vllm',
#         '--enable-prefix-caching',
#         '--default-chat-template-kwargs',
#         '{"preserve_thinking": true}',
#         '--reasoning-parser',
#         'qwen3',
#         '--max-model-len',
#         str(VLLM_MAX_MODEL_LEN),
#     ]
#     print('Starting vLLM OpenAI server:', ' '.join(cmd), flush=True)
#     process = subprocess.Popen(cmd, env=vllm_env(), stdout=log_handle, stderr=subprocess.STDOUT, text=True)
#     VLLM_SERVER_PID.write_text(str(process.pid), encoding='utf-8')
#     wait_for_vllm_server()
#
#
# def run_vllm_api_smoke_test() -> None:
#     payload = {
#         'model': SERVED_MODEL_NAME,
#         'messages': [{'role': 'user', 'content': 'Answer in one short sentence: what is 2 + 2?'}],
#         'temperature': 0.0,
#         'max_tokens': 96,
#         'chat_template_kwargs': {'enable_thinking': False},
#     }
#     response = request_json(f'{VLLM_BASE_URL}/chat/completions', payload=payload, timeout=120)
#     generated = response['choices'][0]['message'].get('content', '').strip()
#     print('\n' + '=' * 88, flush=True)
#     print('VLLM OPENAI SERVER QWEN SMOKE TEST REAL MODEL OUTPUT', flush=True)
#     print('Generated:', generated, flush=True)
#     print('=' * 88 + '\n', flush=True)
#
#
# print(f'vLLM wheelhouse path: {WHEELHOUSE}', flush=True)
# print(f'Qwen model path: {MODEL_PATH}', flush=True)
# assert_expected_cuda_gpu()
# missing = [str(path) for path in (WHEELHOUSE, MODEL_PATH) if not path.exists()]
# if missing:
#     raise FileNotFoundError('Missing attached dataset path(s): ' + ', '.join(missing))
# start_vllm_server()
# run_vllm_api_smoke_test()
# setup_env = {
#     'USE_TF': '0',
#     'TRANSFORMERS_NO_TF': '1',
#     'TRANSFORMERS_NO_TORCHVISION': '1',
#     'VLLM_NO_USAGE_STATS': '1',
#     'PYTHONPATH': str(SITE_PACKAGES) + os.pathsep + os.environ.get('PYTHONPATH', ''),
#     'LOCAL_ANALYZER_BASE_URL': VLLM_BASE_URL,
#     'OPENAI_BASE_URL': VLLM_BASE_URL,
#     'LOCAL_ANALYZER_PROVIDER': 'vllm',
#     'OPENAI_PROVIDER': 'vllm',
#     'LOCAL_ANALYZER_MODEL_ID': SERVED_MODEL_NAME,
#     'INFERENCE_ANALYZER_MODEL': SERVED_MODEL_NAME,
#     'LOCAL_ANALYZER_APP_NAME': 'ARC3 Agent Harness',
#     'LOCAL_ANALYZER_CONTEXT_WINDOW': str(ANALYZER_CONTEXT_WINDOW),
#     'LOCAL_ANALYZER_MAX_OUTPUT': '0',
#     'LOCAL_ANALYZER_TOOL_STEPS': '0',
#     'LOCAL_ANALYZER_TOOL_TIMEOUT': '30',
#     'LOCAL_ANALYZER_TOOL_OUTPUT_TOKENS': '1024',
#     'LOCAL_ANALYZER_YIELD_SECONDS': '60',
#     'LOCAL_ANALYZER_TEMPERATURE': '0.6',
#     'LOCAL_ANALYZER_TOP_P': '0.95',
#     'LOCAL_ANALYZER_TOP_K': '20',
#     'LOCAL_ANALYZER_ENABLE_THINKING': 'true',
#     'MULTIMODAL_CONTEXT': 'current_grid',
#     'MULTIMODAL_UPSCALE': '4',
# }
# setup_env_path = Path(os.environ['TAAF_KAGGLE_SETUP_ENV'])
# existing_setup_env = {}
# if setup_env_path.exists():
#     existing_setup_env = json.loads(setup_env_path.read_text(encoding='utf-8'))
#     if not isinstance(existing_setup_env, dict):
#         raise RuntimeError('TAAF_KAGGLE_SETUP_ENV must contain a JSON object.')
# existing_setup_env.update(setup_env)
# setup_env_path.write_text(json.dumps(existing_setup_env, indent=2), encoding='utf-8')
#
# PYSETUP
# vLLM wheelhouse path: /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3
# Qwen model path: /kaggle/input/models/foysalemonshanto/qwen3-8-27b-fp8-repacked-v1/pytorch/hf-fp8/1
# CUDA GPU check passed for rtx-pro-6000 x1: ['NVIDIA RTX PRO 6000 Blackwell Server Edition']
# Installing vLLM wheelhouse into /kaggle/working/vllm-site-packages
# Looking in links: /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/aiohappyeyeballs-2.6.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 1))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/aiohttp-3.13.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 2))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/aiosignal-1.4.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 3))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/annotated_doc-0.0.4-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 4))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/annotated_types-0.7.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 5))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/anthropic-0.97.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 6))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/anyio-4.13.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 7))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/apache_tvm_ffi-0.1.10-cp312-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 8))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/astor-0.8.1-py2.py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 9))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/attrs-26.1.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 10))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/blake3-1.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 11))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/cachetools-7.0.6-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 12))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/cbor2-6.0.1-cp312-cp312-manylinux_2_28_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 13))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/certifi-2026.4.22-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 14))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 15))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 16))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/click-8.3.3-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 17))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/cloudpickle-3.1.2-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 18))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/compressed_tensors-0.14.0.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 19))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/cryptography-47.0.0-cp311-abi3-manylinux_2_34_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 20))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/cuda_bindings-12.9.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 21))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/cuda_pathfinder-1.5.4-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 22))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/cuda_python-12.9.4-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 23))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/depyf-0.20.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 24))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/dill-0.4.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 25))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/diskcache-5.6.3-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 26))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/distro-1.9.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 27))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/dnspython-2.8.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 28))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/docstring_parser-0.18.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 29))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/einops-0.8.2-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 30))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/email_validator-2.3.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 31))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/fastapi_cli-0.0.24-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 32))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/fastapi_cloud_cli-0.17.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 33))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/fastapi-0.136.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 34))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/fastar-0.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 35))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/filelock-3.29.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 36))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/flashinfer_cubin-0.6.6-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 37))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/flashinfer_python-0.6.6-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 38))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 39))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/fsspec-2026.4.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 40))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/gguf-0.18.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 41))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/googleapis_common_protos-1.74.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 42))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/grpcio-1.80.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 43))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/h11-0.16.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 44))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/hf_xet-1.4.3-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 45))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/httpcore-1.0.9-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 46))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/httptools-0.7.1-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 47))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/httpx_sse-0.4.3-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 48))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/httpx-0.28.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 49))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/huggingface_hub-0.36.2-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 50))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/idna-3.13-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 51))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/ijson-3.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 52))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/importlib_metadata-8.7.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 53))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/interegular-0.3.3-py37-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 54))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/jinja2-3.1.6-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 55))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/jiter-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 56))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/jmespath-1.1.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 57))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/jsonschema_specifications-2025.9.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 58))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/jsonschema-4.26.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 59))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/lark-1.2.2-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 60))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/llguidance-1.3.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 61))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 62))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/lm_format_enforcer-0.11.3-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 63))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/loguru-0.7.3-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 64))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/markdown_it_py-4.0.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 65))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 66))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/mcp-1.27.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 67))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/mdurl-0.1.2-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 68))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/mistral_common-1.11.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 69))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/model_hosting_container_standards-0.1.14-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 70))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/mpmath-1.3.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 71))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/msgspec-0.21.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 72))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/multidict-6.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 73))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/networkx-3.6.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 74))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 75))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 76))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 77))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 78))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 79))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 80))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 81))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 82))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cudnn_frontend-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 83))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 84))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 85))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 86))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 87))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 88))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 89))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cutlass_dsl_libs_base-4.5.0.dev0-cp312-cp312-manylinux_2_28_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 90))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_cutlass_dsl-4.5.0.dev0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 91))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_ml_py-13.595.45-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 92))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 93))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 94))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_nvshmem_cu12-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 95))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 96))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/openai_harmony-0.0.8-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 97))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/openai-2.33.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 98))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opencv_python_headless-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 99))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opentelemetry_api-1.41.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 100))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opentelemetry_exporter_otlp_proto_common-1.41.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 101))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opentelemetry_exporter_otlp_proto_grpc-1.41.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 102))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opentelemetry_exporter_otlp_proto_http-1.41.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 103))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opentelemetry_exporter_otlp-1.41.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 104))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opentelemetry_proto-1.41.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 105))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opentelemetry_sdk-1.41.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 106))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opentelemetry_semantic_conventions_ai-0.5.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 107))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/opentelemetry_semantic_conventions-0.62b1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 108))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/outlines_core-0.2.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 109))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/packaging-26.2-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 110))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/partial_json_parser-0.2.1.1.post7-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 111))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 112))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/prometheus_client-0.25.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 113))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/prometheus_fastapi_instrumentator-7.1.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 114))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/propcache-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 115))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/protobuf-6.33.6-cp39-abi3-manylinux2014_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 116))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 117))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/py_cpuinfo-9.0.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 118))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 119))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pycountry-26.2.16-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 120))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pycparser-3.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 121))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pydantic_core-2.46.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 122))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pydantic_extra_types-2.11.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 123))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pydantic_settings-2.14.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 124))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pydantic-2.13.3-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 125))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pygments-2.20.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 126))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pyjwt-2.12.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 127))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/python_dotenv-1.2.2-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 128))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/python_json_logger-4.1.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 129))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/python_multipart-0.0.27-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 130))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 131))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/pyzmq-27.1.0-cp312-abi3-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 132))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/quack_kernels-0.4.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 133))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/referencing-0.37.0-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 134))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/regex-2026.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 135))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requests-2.33.1-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 136))
# Processing /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/rich_toolkit-0.19.7-py3-none-any.whl (from -r /kaggle/input/datasets/driessmit1/arc3-vllm-h100-wheelhouse-v3/requirements.lock (line 137))
# ...
# analyzer request failed at action 160: HTTPConnectionPool(host='127.0.0.1', port=1234): Read timed out. (read timeout=359.91931548200046)
# [finished] lf52-271a04aa state=gave_up level=1/10 score=1.82 actions=47 tokens=72188 per-level=26/32,21/81,0/60,0/71,0/205,0/148,0/244,0/109,0/164,0/225 note="tokens=101869"
# [finished] bp35-0a0ad940 state=gave_up level=0/9 score=0.00 actions=25 tokens=85005 per-level=25/21,0/48,0/44,0/38,0/33,0/87,0/86,0/131,0/163 note="tokens=98007"
# [finished] ft09-0d8bbf25 state=gave_up level=2/6 score=14.29 actions=32 tokens=49433 per-level=4/43,7/12,21/23,0/28,0/65,0/37 note="tokens=77975"
# [finished] g50t-5849a774 state=gave_up level=0/7 score=0.00 actions=20 tokens=89925 per-level=20/78,0/175,0/179,0/230,0/96,0/54,0/67 note="tokens=101955"
# [finished] wa30-ee6fef47 state=gave_up level=0/9 score=0.00 actions=64 tokens=101435 per-level=64/71,0/119,0/183,0/98,0/368,0/68,0/79,0/442,0/415 note="tokens=104998"
# [finished] dc22-fdcac232 state=gave_up level=1/6 score=3.11 actions=76 tokens=90559 per-level=73/59,3/102,0/67,0/98,0/324,0/578 note="tokens=90559"
# [finished] tu93-0768757b state=gave_up level=2/9 score=6.67 actions=41 tokens=76647 per-level=18/19,15/16,8/34,0/42,0/123,0/80,0/14,0/23,0/111 note="tokens=77858"
# [finished] ka59-38d34dbb state=gave_up level=1/7 score=3.57 actions=36 tokens=94556 per-level=23/28,13/109,0/51,0/51,0/33,0/132,0/326 note="tokens=98564"
# [finished] tr87-cd924810 state=gave_up level=0/6 score=0.00 actions=54 tokens=81406 per-level=54/54,0/58,0/40,0/45,0/71,0/146 note="tokens=81406"
# [finished] lp85-305b61c3 state=gave_up level=1/8 score=2.78 actions=31 tokens=98238 per-level=8/17,23/38,0/31,0/16,0/41,0/60,0/26,0/159 note="tokens=101231"
# [finished] cn04-2fe56bfb state=gave_up level=0/6 score=0.00 actions=36 tokens=83143 per-level=36/29,0/54,0/85,0/300,0/208,0/113 note="tokens=88483"
# [finished] r11l-495a7899 state=gave_up level=1/6 score=4.76 actions=25 tokens=90973 per-level=9/22,16/33,0/51,0/26,0/52,0/49 note="tokens=90973"
# [finished] ls20-9607627b state=gave_up level=0/7 score=0.00 actions=37 tokens=83434 per-level=37/22,0/123,0/73,0/84,0/96,0/192,0/186 note="tokens=90860"
# [finished] m0r0-492f87ba state=gave_up level=0/6 score=0.00 actions=60 tokens=78786 per-level=60/30,0/111,0/203,0/26,0/500,0/237 note="tokens=78786"
# [finished] sb26-7fbdac44 state=gave_up level=1/8 score=2.78 actions=42 tokens=103407 per-level=10/18,32/28,0/18,0/19,0/31,0/23,0/58,0/18 note="tokens=103407"
# [finished] s5i5-18d95033 state=gave_up level=1/8 score=0.81 actions=52 tokens=101535 per-level=37/20,15/89,0/106,0/54,0/162,0/38,0/86,0/83 note="tokens=101535"
# [finished] sc25-635fd71a state=gave_up level=2/6 score=14.29 actions=39 tokens=72098 per-level=22/36,5/6,12/32,0/83,0/143,0/50 note="tokens=103601"
# [finished] tn36-ef4dde99 state=gave_up level=2/7 score=10.71 actions=57 tokens=100466 per-level=12/32,29/72,16/26,0/40,0/30,0/55,0/62 note="tokens=103177"
# [finished] sp80-589a99af state=gave_up level=0/6 score=0.00 actions=62 tokens=66203 per-level=62/39,0/58,0/25,0/148,0/96,0/152 note="tokens=90240"
# [finished] vc33-5430563c state=gave_up level=3/7 score=21.43 actions=63 tokens=102110 per-level=7/7,9/18,30/44,17/61,0/131,0/34,0/152 note="tokens=102110"
# [finished] re86-8af5384d state=gave_up level=3/8 score=16.67 actions=159 tokens=87649 per-level=36/26,38/42,47/86,38/108,0/189,0/139,0/424,0/241 note="tokens=87649"
# analyzer request failed at action 59: HTTPConnectionPool(host='127.0.0.1', port=1234): Read timed out. (read timeout=66.10047908699926)
# [finished] su15-1944f8ab state=gave_up level=1/9 score=2.22 actions=58 tokens=103817 per-level=22/22,36/42,0/26,0/115,0/36,0/31,0/8,0/40,0/41 note="tokens=103817"
# [finished] ar25-0c556536 state=gave_up level=2/8 score=8.33 actions=86 tokens=103311 per-level=21/32,21/50,44/75,0/37,0/89,0/159,0/233,0/73 note="tokens=105758"
# analyzer request failed at action 47: HTTPConnectionPool(host='127.0.0.1', port=1234): Read timed out. (read timeout=31.944406121999236)
# [finished] cd82-fb555c5d state=gave_up level=1/6 score=4.76 actions=46 tokens=68302 per-level=30/55,16/8,0/41,0/21,0/23,0/23 note="tokens=80814"
# analyzer request failed at action 61: HTTPConnectionPool(host='127.0.0.1', port=1234): Read timed out. (read timeout=154.30504465500053)
# [finished] sk48-d8078629 state=gave_up level=0/8 score=0.00 actions=60 tokens=86538 per-level=60/61,0/177,0/101,0/103,0/230,0/181,0/125,0/92 note="tokens=91396"
# benchmark: regenerated diagnostics in /kaggle/working in 4.30s
# benchmark: anim-20260807-anim-25g-p1
# solver:    duck-harness
# games:     25
# passes:    1
# runs:      25 (won: 0)
# started:   2026-08-23 19:58:16
# ended:     2026-08-23 22:10:58
# duration:  2h 12m 41s
# mean score:    4.76
# median score:  2.78
# total actions: 1308
# total tokens:  2171164
# generated tokens/sec: 272.71 (job wallclock)
# total wallclock: 198097.7s
#
# per-game (mean across passes):
#   ar25-0c556536: score=8.33, levels=2.0/8, actions=86, tokens=103311
#   bp35-0a0ad940: score=0.00, levels=0.0/9, actions=25, tokens=85005
#   cd82-fb555c5d: score=4.76, levels=1.0/6, actions=46, tokens=68302
#   cn04-2fe56bfb: score=0.00, levels=0.0/6, actions=36, tokens=83143
#   dc22-fdcac232: score=3.11, levels=1.0/6, actions=76, tokens=90559
#   ft09-0d8bbf25: score=14.29, levels=2.0/6, actions=32, tokens=49433
#   g50t-5849a774: score=0.00, levels=0.0/7, actions=20, tokens=89925
#   ka59-38d34dbb: score=3.57, levels=1.0/7, actions=36, tokens=94556
#   lf52-271a04aa: score=1.82, levels=1.0/10, actions=47, tokens=72188
#   lp85-305b61c3: score=2.78, levels=1.0/8, actions=31, tokens=98238
#   ls20-9607627b: score=0.00, levels=0.0/7, actions=37, tokens=83434
#   m0r0-492f87ba: score=0.00, levels=0.0/6, actions=60, tokens=78786
#   r11l-495a7899: score=4.76, levels=1.0/6, actions=25, tokens=90973
#   re86-8af5384d: score=16.67, levels=3.0/8, actions=159, tokens=87649
#   s5i5-18d95033: score=0.81, levels=1.0/8, actions=52, tokens=101535
#   sb26-7fbdac44: score=2.78, levels=1.0/8, actions=42, tokens=103407
#   sc25-635fd71a: score=14.29, levels=2.0/6, actions=39, tokens=72098
#   sk48-d8078629: score=0.00, levels=0.0/8, actions=60, tokens=86538
#   sp80-589a99af: score=0.00, levels=0.0/6, actions=62, tokens=66203
#   su15-1944f8ab: score=2.22, levels=1.0/9, actions=58, tokens=103817
#   tn36-ef4dde99: score=10.71, levels=2.0/7, actions=57, tokens=100466
#   tr87-cd924810: score=0.00, levels=0.0/6, actions=54, tokens=81406
#   tu93-0768757b: score=6.67, levels=2.0/9, actions=41, tokens=76647
#   vc33-5430563c: score=21.43, levels=3.0/7, actions=63, tokens=102110
#   wa30-ee6fef47: score=0.00, levels=0.0/9, actions=64, tokens=101435
#
# diagnostics: /kaggle/working/diagnostics.html
# taaf.kaggle: teardown command: "$PYTHON" - <<'PYTEARDOWN'
# import os
# import shutil
# import signal
# import time
# from pathlib import Path
#
# WORKING_DIR = Path(os.environ['TAAF_KAGGLE_WORKING_DIR'])
# pid_path = WORKING_DIR / 'vllm-openai-server.pid'
# site_packages = WORKING_DIR / 'vllm-site-packages'
# if pid_path.exists():
#     try:
#         pid = int(pid_path.read_text(encoding='utf-8').strip())
#         print('Stopping vLLM server', flush=True)
#         os.kill(pid, signal.SIGTERM)
#         deadline = time.monotonic() + 30
#         while time.monotonic() < deadline:
#             try:
#                 os.kill(pid, 0)
#             except OSError:
#                 break
#             time.sleep(1)
#         else:
#             os.kill(pid, signal.SIGKILL)
#     except Exception as exc:
#         print(f'Could not stop vLLM server cleanly: {exc!r}', flush=True)
#     pid_path.unlink(missing_ok=True)
# shutil.rmtree(site_packages, ignore_errors=True)
# print(f'Removed temporary vLLM install at {site_packages}', flush=True)
#
# PYTEARDOWN
# Stopping vLLM server
# Removed temporary vLLM install at /kaggle/working/vllm-site-packages
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py:724: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe srcdoc="&lt;!doctype html&gt;
# &lt;html&gt;&lt;head&gt;&lt;meta charset=&quot;utf-8&quot;&gt;&lt;title&gt;anim-20260807-anim-25g-p1&lt;/title&gt;&lt;style&gt;
# body { background: #1e1e1e; color: #e0e0e0; font-family: -apple-system, system-ui, sans-serif;
#        padding: 20px; max-width: 1400px; margin: 0 auto; line-height: 1.4; }
# h1, h2, h3 { color: #ffffff; }
# table { border-collapse: collapse; margin: 12px 0; }
# th, td { border: 1px solid #3a3a3a; padding: 6px 10px; text-align: left; vertical-align: middle; }
# th { background: #2a2a2a; }
# .pixelart { image-rendering: pixelated; image-rendering: -moz-crisp-edges; image-rendering: crisp-edges;
#             vertical-align: middle; }
# a { color: #9bd1ff; }
# a:visited { color: #c9b1ff; }
# pre { background: #2a2a2a; padding: 10px; border-radius: 4px; overflow-x: auto; }
# .game-name { display: inline-flex; align-items: center; gap: 6px; }
# .summary-box { background: #2a2a2a; padding: 12px 16px; border-radius: 4px; margin: 12px 0; }
# .game-link { display: inline-flex; align-items: center; gap: 6px; padding: 6px 10px;
#              margin: 4px; background: #2a2a2a; border-radius: 4px; text-decoration: none; }
# .intro { color: #b8b8b8; font-style: italic; margin: 4px 0 16px 0; max-width: 70ch; }
# .design-note { background: #3a2a1e; border-left: 4px solid #ffb47a; padding: 10px 14px;
#                margin: 12px 0; border-radius: 4px; }
# .curve-note { background: #1e2e2a; border-left: 4px solid #74a98c; padding: 10px 14px;
#               margin: 12px 0; border-radius: 4px; max-width: 80ch; }
# .curve-note p { margin: 6px 0; }
# .curve-note code { background: #2a3a36; padding: 1px 4px; border-radius: 2px; }
# .in-flight-banner { background: #1e2e3a; border-left: 4px solid #5a92c8; padding: 12px 16px;
#                     margin: 12px 0; border-radius: 4px; font-size: 1.05em; color: #cfe2f3; }
# .weights-banner { background: #2a2a1e; border-left: 4px solid #f0d878; padding: 12px 16px;
#                   margin: 12px 0; border-radius: 4px; color: #f4e8c0; }
# .weights-banner p { margin: 4px 0; }
# .weights-banner ul { margin: 4px 0 0 24px; padding: 0; }
# /* Folder-tab score selector: pure-CSS radio + sibling-selector. The
#    active tab visually merges into the panel below by matching the
#    panel&#x27;s background and hiding its bottom border. */
# .scorer-tabs &gt; input[type=&quot;radio&quot;] { display: none; }
# .scorer-tabs .tab-row { display: flex; border-bottom: 2px solid #5a92c8; margin: 20px 0 0 0; }
# .scorer-tabs .tab-label { padding: 8px 18px; background: #2a2a2a; color: #b8b8b8;
#                           border: 2px solid #3a3a3a; border-bottom: none;
#                           border-radius: 6px 6px 0 0; margin-right: 4px;
#                           margin-bottom: -2px; cursor: pointer; user-select: none;
#                           font-weight: 500; }
# .scorer-tabs .tab-label:hover { color: #cfe2f3; }
# .scorer-tabs .tab-panel { display: none; padding: 16px 4px; }
# .scorer-tabs &gt; input#scorer-arc:checked ~ .tab-row label[for=&quot;scorer-arc&quot;],
# .scorer-tabs &gt; input#scorer-weighted:checked ~ .tab-row label[for=&quot;scorer-weighted&quot;],
# .scorer-tabs &gt; input#scorer-levels:checked ~ .tab-row label[for=&quot;scorer-levels&quot;] {
#     background: #1e1e1e; color: #ffffff; border-color: #5a92c8; border-bottom-color: #1e1e1e;
# }
# .scorer-tabs &gt; input#scorer-arc:checked ~ #panel-arc,
# .scorer-tabs &gt; input#scorer-weighted:checked ~ #panel-weighted,
# .scorer-tabs &gt; input#scorer-levels:checked ~ #panel-levels { display: block; }
# .scorer-tabs .scorer-desc { color: #b8b8b8; font-style: italic; margin: 4px 0 12px 0; max-width: 80ch; }
# /* Two-level budget × scorer tab widget (R4.12 comparison statistics).
#    A panel shows only when its budget tab AND scorer tab are both
#    checked — the standard two-radio-group CSS-only selection. The budget
#    row is amber, the scorer row blue, to read as nested. */
# .bs-tabs &gt; input[type=&quot;radio&quot;] { display: none; }
# .bs-tabs .tab-row { display: flex; flex-wrap: wrap; }
# .bs-tabs .budget-row { border-bottom: 2px solid #e0a060; margin: 20px 0 0 0; }
# .bs-tabs .scorer-row { border-bottom: 2px solid #5a92c8; margin: 14px 0 0 0; }
# .bs-tabs .tab-label { padding: 8px 18px; background: #2a2a2a; color: #b8b8b8;
#                       border: 2px solid #3a3a3a; border-bottom: none;
#                       border-radius: 6px 6px 0 0; margin-right: 4px;
#                       margin-bottom: -2px; cursor: pointer; user-select: none; font-weight: 500; }
# .bs-tabs .tab-label:hover { color: #cfe2f3; }
# .bs-tabs .tab-panel { display: none; padding: 16px 4px; }
# .bs-tabs &gt; #bs-b-full:checked ~ .budget-row label[for=&quot;bs-b-full&quot;],
# .bs-tabs &gt; #bs-b-capped:checked ~ .budget-row label[for=&quot;bs-b-capped&quot;] {
#     background: #1e1e1e; color: #ffffff; border-color: #e0a060; border-bottom-color: #1e1e1e;
# }
# .bs-tabs &gt; #bs-s-arc:checked ~ .scorer-row label[for=&quot;bs-s-arc&quot;],
# .bs-tabs &gt; #bs-s-weighted:checked ~ .scorer-row label[for=&quot;bs-s-weighted&quot;],
# .bs-tabs &gt; #bs-s-levels:checked ~ .scorer-row label[for=&quot;bs-s-levels&quot;] {
#     background: #1e1e1e; color: #ffffff; border-color: #5a92c8; border-bottom-color: #1e1e1e;
# }
# .bs-tabs &gt; #bs-b-full:checked ~ #bs-s-arc:checked ~ #bs-p-full-arc,
# .bs-tabs &gt; #bs-b-full:checked ~ #bs-s-weighted:checked ~ #bs-p-full-weighted,
# .bs-tabs &gt; #bs-b-full:checked ~ #bs-s-levels:checked ~ #bs-p-full-levels,
# .bs-tabs &gt; #bs-b-capped:checked ~ #bs-s-arc:checked ~ #bs-p-capped-arc,
# .bs-tabs &gt; #bs-b-capped:checked ~ #bs-s-weighted:checked ~ #bs-p-capped-weighted,
# .bs-tabs &gt; #bs-b-capped:checked ~ #bs-s-levels:checked ~ #bs-p-capped-levels { display: block; }
# .bs-tabs .scorer-desc { color: #b8b8b8; font-style: italic; margin: 4px 0 12px 0; max-width: 80ch; }
# .per-game-grid { display: flex; flex-direction: column; gap: 12px; margin: 12px 0; }
# .per-game-card { display: flex; align-items: center; gap: 12px; padding: 12px;
#                  background: #2a2a2a; border-radius: 4px; flex-wrap: wrap; }
# .per-game-card img { max-width: 360px; height: auto; border-radius: 4px; }
# .per-game-header { min-width: 160px; }
# /* Pairwise p-value matrices (&gt;2-run comparison). */
# .summary-box h4 { margin: 14px 0 4px 0; }
# table.pmatrix td { text-align: center; }
# td.pval-sig { font-weight: bold; color: #9be8a8; }
# td.pval-na { color: #888; }
# td.pval-diag { color: #666; }
# .pval-arrow { color: #e0a060; font-weight: bold; }
# &lt;/style&gt;&lt;/head&gt;
# &lt;body&gt;
# &lt;h1&gt;anim-20260807-anim-25g-p1&lt;/h1&gt;&lt;p class=&quot;intro&quot;&gt;Diagnostics for one TAAF benchmark run — a single solver played each game over a fixed number of passes. Plots track score-vs-cost across the run; the table lists every (game, pass) cell, with the movie cell linking to a video of that play-through.&lt;/p&gt;&lt;div class=&quot;summary-box&quot;&gt;&lt;p&gt;Solver: &lt;code&gt;duck-harness&lt;/code&gt;&lt;/p&gt;&lt;p&gt;25 games × 1 pass = 25 runs&lt;/p&gt;&lt;p&gt;Started: &lt;code&gt;2026-08-23 19:58:16&lt;/code&gt;&lt;/p&gt;&lt;p&gt;Ended: &lt;code&gt;2026-08-23 22:10:58&lt;/code&gt;&lt;/p&gt;&lt;p&gt;Duration: &lt;code&gt;2h 12m 41s&lt;/code&gt;&lt;/p&gt;&lt;details&gt;&lt;summary&gt;git status&lt;/summary&gt;&lt;pre&gt;git status:
#   ARC3-Inference                   9158303     DIRTY  feature/animation-awareness  feat: proactively suggest animation retrieval when stuck (s…
#   tufa-arc-agi-framework           9158303     DIRTY  feature/animation-awareness  feat: proactively suggest animation retrieval when stuck (s…&lt;/pre&gt;&lt;/details&gt;&lt;/div&gt;&lt;div class=&quot;scorer-tabs&quot;&gt;&lt;input type=&quot;radio&quot; name=&quot;scorer&quot; id=&quot;scorer-arc&quot; checked&gt;&lt;input type=&quot;radio&quot; name=&quot;scorer&quot; id=&quot;scorer-weighted&quot;&gt;&lt;input type=&quot;radio&quot; name=&quot;scorer&quot; id=&quot;scorer-levels&quot;&gt;&lt;div class=&quot;tab-row&quot;&gt;&lt;label for=&quot;scorer-arc&quot; class=&quot;tab-label&quo
